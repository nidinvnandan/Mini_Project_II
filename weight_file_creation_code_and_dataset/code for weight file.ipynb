# %% [markdown]
# ## Code for creating the .pt model file for the detection task

# %%
#importing the Yolov5 from thier official githubrepo

# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-245-g3d8f004 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %% [markdown]
# Here we have created our own dataset which contains images and labels corresponding to different classes and we have created a "dat.yaml" file which defains tha path for the train and val folder in our dataset and this "data.yaml" file placed inside the data folder in "yolov5" folder. Using this path the model will access the dataset and employee the pretrained model to train our own dataset for the detection of accident

# %%
#initializing the training part in the yolov5 pretrained model with an epoch size of 150 and data of data.yaml
# !python train.py --img 640 --batch 16 --epochs 150 --data data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-22 15:56:04.980248: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-22 15:56:04.980309: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-22 15:56:04.980358: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# Now we have our own .pt weight model which is capable of detecting the accident in the main file which can then be integrated with the main_code for creation of a model capable of detecting and alerting the occurence of accident in a video
